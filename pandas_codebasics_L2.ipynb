# %% [markdown]
# <a href="https://colab.research.google.com/github/SouparnaChatterjee/pandas-5.24/blob/main/pandas_codebasics_L2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('weather_data (1).csv')
df.head(5)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
#in pandas after df we usually enclose in []
df['event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
#when multiple events are indicated, we use multiple []
df[['event', 'day']]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/6/2017

# %%
df[['temperature', 'event', 'day']]
# Out:
#    temperature  event       day
# 0           32   Rain  1/1/2017
# 1           35  Sunny  1/2/2017
# 2           28   Snow  1/3/2017
# 3           24   Snow  1/4/2017
# 4           32   Rain  1/5/2017
# 5           31  Sunny  1/6/2017

# %%
#df['reference column'].fxn()
df['temperature'].max()
# Out:
# 35

# %%
#finding mean
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df[df['temperature']>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
#[df['temperature']]
#[df.temperature] is equal to df['temperature']
df[df.temperature>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
df[df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df[df.temperature==df.temperature.max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
#prints specific column df['day']
df['day'][df.temperature==df.temperature.max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df[['day','temperature']][df.temperature==df['temperature'].max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.index
# Out:
# Index([32, 35, 28, 24, 32, 31], dtype='int64', name='temperature')

# %%
#we want to change the index fro the sl.no column to the day column.... we use (inplace=True) so that the original data is changed
#if we dont use (inplace=True), a copy of the data is changed
df.set_index('day', inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.loc['1/3/2017']
#we use df.loc[] to access data by index
# Out:
# temperature      28
# windspeed         2
# event          Snow
# Name: 1/3/2017, dtype: object

# %%
#we want to reset index to the original; one ... so we use resset_index
#in set index, to make the change to an original copy, we use inplace=True... we do the same in case of reset_index
df.reset_index(inplace=True)

# %%
df.set_index('event', inplace=True)

# %%
#df.loc[] has [] ie square brackets
df.loc['Snow']
# Out:
#             day  temperature  windspeed
# event
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
