# %% [markdown]
# <a href="https://colab.research.google.com/github/SouparnaChatterjee/pandas-5.24/blob/main/pandas_codebasics_L4_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#df = pd.read_csv("stock_data.csv", skiprows=1)
#this is the same as the following... used to skip the row numbered 0 and starts reading from 1
#df = pd.read_csv("stock_data.csv", header=1)

#na_values=[]     indicates that for the values enclosed in [] we will substitute NaN
df = pd.read_csv("stock_data.csv", header=None, na_values=
 {
      'eps': ['n.a.','not available'],
      'revenue': ['n.a.','not available',-1]})
df

#since this is a csv file, use names=[] her
#in case of a python dictionary iew DataFrame, we use columns
# Out:
#          0              1        2      3              4
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df.columns
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %%
df.to_csv("new.csv", header=False)
